# %%
# !pip install pygame
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for pygame from https://files.pythonhosted.org/packages/82/61/93ae7afbd931a70510cfdf0a7bb0007540020b8d80bc1d8762ebdc46479b/pygame-2.5.2-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#     --------------------------------------- 0.2/10.8 MB 6.9 MB/s eta 0:00:02
#    - -------------------------------------- 0.3/10.8 MB 4.2 MB/s eta 0:00:03
#    - -------------------------------------- 0.5/10.8 MB 3.9 MB/s eta 0:00:03
#    -- ------------------------------------- 0.6/10.8 MB 3.2 MB/s eta 0:00:04
#    -- ------------------------------------- 0.7/10.8 MB 2.9 MB/s eta 0:00:04
#    --- ------------------------------------ 0.9/10.8 MB 3.1 MB/s eta 0:00:04
#    --- ------------------------------------ 1.0/10.8 MB 2.9 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.2/10.8 MB 3.0 MB/s eta 0:00:04
# ...

# %%
import pygame
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
x = pygame.init()
gamewindow = pygame.display.set_mode((1280,720))

# %%
gamewindow
# Out:
# <Surface(1280x720x32 SW)>
